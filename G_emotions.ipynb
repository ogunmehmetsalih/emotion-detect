# %%
import numpy as np
import pandas as pd 
import os

import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from tensorflow.keras.applications import VGG16, InceptionResNetV2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from keras import regularizers
from tensorflow.keras.optimizers import Adam,RMSprop,SGD,Adamax
import matplotlib.pyplot as plt
from keras.utils import plot_model
train_dir = "C:\\Users\\admin\\Desktop\\f_2013\\train"
test_dir = "C:\\Users\\admin\\Desktop\\f_2013\\test"   
img_size = 48

# %%
train_datagen = ImageDataGenerator(#rotation_range = 180,
                                         width_shift_range = 0.1,
                                         height_shift_range = 0.1,
                                         horizontal_flip = True,
                                         rescale = 1./255,
                                         #zoom_range = 0.2,
                                         validation_split = 0.2
                                        )
validation_datagen = ImageDataGenerator(rescale = 1./255)

train_generator = train_datagen.flow_from_directory(directory = train_dir,
                                                    target_size = (img_size,img_size),
                                                    batch_size = 32,
                                                    color_mode = "grayscale",
                                                    class_mode = "categorical",
                                                    subset = "training"
                                                   )
validation_generator = validation_datagen.flow_from_directory( directory = test_dir,
                                                              target_size = (img_size,img_size),
                                                              batch_size = 32,
                                                              color_mode = "grayscale",
                                                              class_mode = "categorical"
                                                             )
# Out:
# Found 22968 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
model= tf.keras.models.Sequential()
model.add(Conv2D(32, kernel_size=(3,3), padding='same', activation='relu', input_shape=(48, 48,1)))
model.add(Conv2D(64,(3,3), padding='same', activation='relu' ))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))


model.add(Conv2D(128,(3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.10))
    

model.add(Conv2D(512,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten()) 
model.add(Dense(256,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
    
model.add(Dense(512,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(7, activation='softmax'))
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0001), 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

epochs = 60
batch_size = 32
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 48, 48, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 48, 48, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 48, 48, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 22, 22, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 22, 22, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 11, 11, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 11, 11, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 9, 9, 512)           │         590,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 9, 9, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       2,097,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 7)                   │           3,591 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,921,479 (11.14 MB)
#  Trainable params: 2,918,535 (11.13 MB)
#  Non-trainable params: 2,944 (11.50 KB)

# %%
mc = ModelCheckpoint('best_model.keras', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

history = model.fit(x = train_generator,epochs = epochs,validation_data = validation_generator,callbacks=[mc])
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
fig.set_size_inches(12,4)

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training Accuracy vs Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training Loss vs Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')


plt.show()
# Out:
# Epoch 1/60
# C:\Users\admin\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.2064 - loss: 4.4179
# Epoch 1: val_accuracy improved from -inf to 0.35985, saving model to best_model.keras
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 459s 626ms/step - accuracy: 0.2065 - loss: 4.4175 - val_accuracy: 0.3598 - val_loss: 3.4661
# Epoch 2/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.2890 - loss: 3.7077
# Epoch 2: val_accuracy improved from 0.35985 to 0.38924, saving model to best_model.keras
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 397s 553ms/step - accuracy: 0.2890 - loss: 3.7076 - val_accuracy: 0.3892 - val_loss: 3.0882
# Epoch 3/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.3358 - loss: 3.2461
# Epoch 3: val_accuracy improved from 0.38924 to 0.43215, saving model to best_model.keras
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 406s 564ms/step - accuracy: 0.3358 - loss: 3.2459 - val_accuracy: 0.4322 - val_loss: 2.6914
# Epoch 4/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.3590 - loss: 2.8693
# Epoch 4: val_accuracy did not improve from 0.43215
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 403s 562ms/step - accuracy: 0.3590 - loss: 2.8692 - val_accuracy: 0.3702 - val_loss: 2.6321
# Epoch 5/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0
60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.6489 - loss: 1.0962
# Epoch 48: val_accuracy did not improve from 0.64252
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 376s 523ms/step - accuracy: 0.6489 - loss: 1.0962 - val_accuracy: 0.6294 - val_loss: 1.1794
# Epoch 49/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.6490 - loss: 1.1043
# Epoch 49: val_accuracy improved from 0.64252 to 0.64712, saving model to best_model.keras
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 376s 524ms/step - accuracy: 0.6490 - loss: 1.1043 - val_accuracy: 0.6471 - val_loss: 1.1249
# Epoch 50/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - accuracy: 0.6540 - loss: 1.0885
# Epoch 50: val_accuracy did not improve from 0.64712
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 376s 524ms/step - accuracy: 0.6540 - loss: 1.0885 - val_accuracy: 0.6386 - val_loss: 1.1542
# Epoch 51/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.6583 - loss: 1.0861
# Epoch 51: val_accuracy did not improve from 0.64712
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 376s 523ms/step - accuracy: 0.6583 - loss: 1.0861 - val_accuracy: 0.6452 - val_loss: 1.1507
# Epoch 52/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.6570 - loss: 1.0882
# Epoch 52: val_accuracy did not improve from 0.64712
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 376s 523ms/step - accuracy: 0.6570 - loss: 1.0882 - val_accuracy: 0.6415 - val_loss: 1.1362
# Epoch 53/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - accuracy: 0.6624 - loss: 1.0851
# Epoch 53: val_accuracy did not improve from 0.64712
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 377s 524ms/step - accuracy: 0.6624 - loss: 1.0851 - val_accuracy: 0.6402 - val_loss: 1.1450
# Epoch 54/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - accuracy: 0.6606 - loss: 1.0774
# Epoch 54: val_accuracy did not improve from 0.64712
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 376s 524ms/step - accuracy: 0.6606 - loss: 1.0774 - val_accuracy: 0.6413 - val_loss: 1.1630
# Epoch 55/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.6667 - loss: 1.0653
# Epoch 55: val_accuracy improved from 0.64712 to 0.64962, saving model to best_model.keras
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 377s 524ms/step - accuracy: 0.6667 - loss: 1.0653 - val_accuracy: 0.6496 - val_loss: 1.1429
# Epoch 56/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.6619 - loss: 1.0748
# Epoch 56: val_accuracy did not improve from 0.64962
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 376s 524ms/step - accuracy: 0.6619 - loss: 1.0748 - val_accuracy: 0.6280 - val_loss: 1.1736
# Epoch 57/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.6623 - loss: 1.0740
# Epoch 57: val_accuracy did not improve from 0.64962
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 376s 524ms/step - accuracy: 0.6623 - loss: 1.0741 - val_accuracy: 0.6368 - val_loss: 1.1721
# Epoch 58/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.6660 - loss: 1.0671
# Epoch 58: val_accuracy did not improve from 0.64962
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 376s 524ms/step - accuracy: 0.6660 - loss: 1.0671 - val_accuracy: 0.6443 - val_loss: 1.1486
# Epoch 59/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - accuracy: 0.6703 - loss: 1.0626
# Epoch 59: val_accuracy did not improve from 0.64962
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 377s 525ms/step - accuracy: 0.6703 - loss: 1.0626 - val_accuracy: 0.6408 - val_loss: 1.1628
# Epoch 60/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.6724 - loss: 1.0580
# Epoch 60: val_accuracy did not improve from 0.64962
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 378s 526ms/step - accuracy: 0.6723 - loss: 1.0580 - val_accuracy: 0.6439 - val_loss: 1.1397

# %%
model.save("my_model.keras")
